# %% [markdown]
# # Laboration 1 i Maskininlärning:
#
# ## **Disease prediction**

# %%
# Importera alla klasser från ml_models.py
from cvd_models import DataLoader, DataProcessor, DataVisualizer, DataPreparer, ModelTrainer, EnsembleModeler

# %%
# Ange sökvägen till din CSV-fil
data_path = "/Users/paraugustsson/Machine-learning-AI24-1/cardio_train.csv" # Anpassa sökvägen

# Skapa DataLoader-objektet och läs in datan
loader = DataLoader(data_path)
df = loader.load_data()

# Visa de första raderna för att bekräfta att inläsningen lyckades
df.head()
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
# Skapa ett DataProcessor-objekt
processor = DataProcessor(df)

# Kör den initiala rensningen
df_clean = processor.initial_data_process()

# Utför feature engineering för BMI och blodtryck
df_clean = processor.feature_engineering_bmi()
df_clean = processor.feature_engineering_bp()

# Visa de bearbetade data (exempelvis med .head())
df_clean.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo       cholesterol    gluc smoke  \
# 0   50    Male     168    62.0    110     80            Normal  Normal    No
# 1   55  Female     156    85.0    140     90  Way Above Normal  Normal    No
# 2   52  Female     165    64.0    130     70  Way Above Normal  Normal    No
# 3   48    Male     169    82.0    150    100            Normal  Normal    No
# 4   48  Female     156    56.0    100     60            Normal  Normal    No
#
#   alco  active cardio    bmi          bmi_cat                bp_cat
# 0   No       1     No  21.97     Normal Range  Hypertension Stage 1
# 1   No       1    Yes  34.93  Obese (Class I)  Hypertension Stage 2
# 2   No       0    Yes  23.51     Normal Range  Hypertension Stage 1
# 3   No       1    Yes  28.71       Overweight  Hypertension Stage 2
# 4   No       0     No  23.01     Normal Range                Normal

# %%
# Skapa ett DataVisualizer-objekt med den bearbetade datan
visualizer = DataVisualizer(df_clean)

# Visa en översikt för EDA (t.ex. countplots, histogram, pie-charts)
visualizer.eda_overview()

# Visa översikten över sjukdomar med stapeldiagram
visualizer.dicease_overwiev()

# Visa korrelationsmatrisen
visualizer.correlation_heatmap()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       2 visualizer = DataVisualizer(df_clean)
#       4 # Visa en översikt för EDA (t.ex. countplots, histogram, pie-charts)
# ----> 5 visualizer.eda_overview()
#       7 # Visa översikten över sjukdomar med stapeldiagram
#       8 visualizer.dicease_overwiev()
#
# File ~/Machine-learning-AI24-1/cvd_models.py:128, in DataVisualizer.eda_overview(self)
#     125 ax = plt.subplots(4, 2, figsize=(20, 15))
#     127 # Countplot: CVD-distribution
# --> 128 sns.countplot(x="cardio", data=self.df, palette="Set2", ax=ax[0, 0])
#     129 ax[0, 0].set_title("Cardiovascular Disease (CVD) Distribution")
#     130 ax[0, 0].set_xlabel("cardio")
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
from cvd_models import DataLoader, DataProcessor, DataVisualizer, DataPreparer, ModelTrainer, EnsembleModeler

# %%
# Skapa ett DataVisualizer-objekt med den bearbetade datan
visualizer = DataVisualizer(df_clean)

# Visa en översikt för EDA (t.ex. countplots, histogram, pie-charts)
visualizer.eda_overview()

# Visa översikten över sjukdomar med stapeldiagram
visualizer.decease_overwiev()

# Visa korrelationsmatrisen
visualizer.correlation_heatmap()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2 visualizer = DataVisualizer(df_clean)
#       4 # Visa en översikt för EDA (t.ex. countplots, histogram, pie-charts)
# ----> 5 visualizer.eda_overview()
#       7 # Visa översikten över sjukdomar med stapeldiagram
#       8 visualizer.decease_overwiev()
#
# File ~/Machine-learning-AI24-1/cvd_models.py:128, in DataVisualizer.eda_overview(self)
#     125 ax = plt.subplots(4, 2, figsize=(20, 15))
#     127 # Countplot: CVD-distribution
# --> 128 sns.countplot(x="cardio", data=self.df, palette="Set2", ax=ax[0, 0])
#     129 ax[0, 0].set_title("Cardiovascular Disease (CVD) Distribution")
#     130 ax[0, 0].set_xlabel("cardio")
#
# TypeError: tuple indices must be integers or slices, not tuple
