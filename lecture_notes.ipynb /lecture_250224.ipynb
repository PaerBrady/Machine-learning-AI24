# %% [markdown]
# ## Lektion 24/2
#
# Vikten av matris det som vi lärt oss. Hur många enheter av xxx för reklam tex
#
# **Allmän linjär regression**
#
# Vi söker linjära approximationer (sanningar) givet ett stickprov (träningsdata).
#
# Se Graf ()
#
# Derivator ???
#
# Lokalt i små områden bar approximationer. Kan man göra (kallas för local regression) - läs mer i boken kap 7 (inte så viktigt i linjär regression)
#
# Y = β0 + β1Χ1 + ε -  linjär ekvation
#
# Y = f(x) (ett x så en dimension) men utritad i en graf så måste den bli 2 dimensioner.
#
# Se matris (lecture notes Raphael)
#
# Utvidgar till en dimension till därför vi sätter B0 (ettan) för att kunna rita ut den.
#
# B0, B1 skall bestämmas
#
# Min **C** (B) =
#
# Se anteckningar
#
# Väntvärdet (medlet) är linjärt med koefficienten?
#
# SE ANTECKNINGAR
#
# #### generell additiv modell (GAM generalized ad
#
# g(E(Y)) = beta\_0 + f\_1(X\_1) + f\_2(X\_2) + dots + f\_p(X\_p)
#
#
# ….
#
#
# MSE = BIas ^2 + varians + brus (irreducibel)
#
# Reguljärisering minskar varians men tenderar att ökar bias
#
# Undvika underfit för enkel modell
# lpg bias , hög varians
# (hög precision, låg noggrannhet)
# Overfit (för komplicerad)
# hög bias, låg varians
# (låg precision, hög noggrannhet)
#
#   Regu
#
#
# J(beta) = sum (y\_i - hat{y}\_i)^2 + lambda sum beta\_j^2
# Lasso L1 där |B| tenderar att sätt signifikanta koefficienter till 0.
#
# Lambda effekten?
#
# Man grå lägre bias när man reguljäriserar? Kom ihåg det.
# Är inte så känsliga för outliers.
